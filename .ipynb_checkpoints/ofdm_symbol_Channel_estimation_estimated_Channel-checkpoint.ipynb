# %%
import numpy as np
from QAM_EncoderDecoder import * 
import commpy
from scipy.io.wavfile import write, read
import matplotlib.pyplot as plt
# %matplotlib inline

N = 1024
prefix_no = 32
Fs = 441000
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b92ca39e4a9f> in <module>
#       1 import numpy as np
#       2 from QAM_EncoderDecoder import *
# ----> 3 import commpy
#       4 from scipy.io.wavfile import write, read
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'commpy'

# %% [markdown]
# ## 1. Generate random symbols

# %%
random_symbol = np.random.randint(0,100, int(50/4))
random_symbol
# Out:
# array([22, 38,  6, 33, 96, 39, 37, 97, 61, 12, 49, 47])

# %%
bin_strings=''
for byte in random_symbol:
    binary_string = '{0:08b}'.format(byte)
    bin_strings+=binary_string
bin_strings
# Out:
# '000101100010011000000110001000010110000000100111001001010110000100111101000011000011000100101111'

# %%
symbols = encode_bitstr2symbols(bin_strings)
len(symbols)
# Out:
# about to do encode_bitstr2symbols encoding
# encode_bitstr2symbols encoding finished
# 48

# %%
frames = np.fft.ifft(symbols)
frames.shape
# Out:
# (48,)

# %%
frames
# Out:
# array([ 1.66666667e-01+0.29166667j,  1.45385016e-02+0.09197606j,
#        -6.77018520e-02-0.10401983j, -7.53679551e-02+0.03026828j,
#        -1.76335450e-01-0.07775106j,  6.06909822e-02+0.13744293j,
#        -2.18443362e-01-0.05892557j, -2.90547973e-01-0.07219132j,
#        -5.54219591e-02+0.1651709j , -1.03019735e-01+0.00586051j,
#        -2.49958509e-02+0.03005087j, -1.37174915e-01+0.05629969j,
#         4.16666667e-01+0.29166667j,  6.75190474e-02-0.18164088j,
#         3.82390695e-02-0.02172583j,  1.07155188e-02+0.09816473j,
#         5.84134912e-02+0.03199788j,  7.98186011e-02-0.05205908j,
#         1.00592232e-01-0.05892557j, -5.00607334e-03-0.24275655j,
#        -3.19978830e-02-0.00558227j,  6.47860769e-02+0.0196864j ,
#         5.44586335e-02+0.19775687j,  1.94179861e-01+0.11411931j,
#         3.70074342e-17+0.45833333j, -1.63752762e-01-0.18140374j,
#        -4.61335983e-02+0.05118861j,  1.68811317e-01-0.12371164j,
#        -2.08333333e-02-0.11941773j, -2.36391679e-01+0.03531809j,
#         1.35110029e-01+0.05892557j,  1.57983784e-01+0.06041794j,
#         2.74919842e-01+0.17633545j, -3.92391632e-02-0.14811941j,
#         5.54979679e-02-0.22721965j,  1.48948293e-01+0.0762645j ,
#         8.33333333e-02-0.04166667j,  3.09366113e-01+0.21006433j,
#         7.55963808e-02+0.07455705j, -2.70825547e-01+0.1619453j ,
#         3.05421959e-01-0.12350423j,  3.48778621e-02+0.10696896j,
#        -1.72588984e-02+0.05892557j,  7.65660290e-02+0.02685903j,
#        -2.08333333e-02-0.04724894j, -8.91938452e-02-0.04409417j,
#        -8.49607505e-02-0.00058808j,  2.17176622e-02-0.18567926j])

# %% [markdown]
# ##  2 Convolv with a simple channel:

# %%
sim_channel = np.array([0.5, 0.25, 0.0, 0.25])
plt.plot(sim_channel)

# %%
chan_fft = np.fft.fft(sim_channel, 1024)
chan_fft /= np.linalg.norm(chan_fft)
plt.plot(np.linspace(0,fs/2,int(N/2)),np.abs(chan_fft)[0:int(N/2)])

# %%
frames.shape
# Out:
# (48,)

# %%
channel_out = np.convolve(frames, sim_channel)

# %%
channel_out.shape
# Out:
# (51,)

# %%
plt.plot(channel_out)
# Out:
# C:\Users\H1937\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(frames)
# Out:
# C:\Users\H1937\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## 3. Decode the received audio

# %%
recorded = channel_out[0:48]
recorded.shape
# Out:
# (48,)

# %%
recorded_frequency = np.fft.fft(recorded)

# %%
freq_response = recorded_frequency / np.array(symbols)
freq_response
# Out:
# array([ 1.06834501+0.03566519j,  1.00700281-0.20119075j,
#         0.93779416-0.3169489j ,  0.81635045-0.25081717j,
#         0.79034917-0.37398031j,  0.6103444 -0.31359478j,
#         0.48477288-0.41673817j,  0.44234411-0.2389736j ,
#         0.42057317-0.24146509j,  0.40004485-0.16175124j,
#         0.36245736-0.0896544j ,  0.45899806-0.00188275j,
#         0.50611442-0.01633106j,  0.57171437-0.01809391j,
#         0.60556154-0.06422095j,  0.64590341-0.12579542j,
#         0.64608657-0.20648317j,  0.54746876-0.30207582j,
#         0.49621251-0.31287499j,  0.39984786-0.33450914j,
#         0.29391185-0.32021436j,  0.11459683-0.30723932j,
#         0.14214749-0.27036583j, -0.01709564-0.18799593j,
#         0.0469578 +0.05675836j, -0.03070711+0.18273972j,
#         0.12718771+0.18121315j,  0.21132163+0.26250437j,
#         0.31347416+0.30913246j,  0.3752554 +0.44859879j,
#         0.56297686+0.36836443j,  0.58746421+0.23525897j,
#         0.67814679+0.22061606j,  0.58865214+0.13392003j,
#         0.57228328+0.0640577j ,  0.56495939-0.01623837j,
#         0.52720759+0.00505614j,  0.45946242+0.02666729j,
#         0.36852861+0.04902181j,  0.38286945+0.1575906j ,
#         0.39393764+0.2455682j ,  0.39953306+0.25857152j,
#         0.52625067+0.39443971j,  0.64760395+0.35083659j,
#         0.755993  +0.42221202j,  0.77918133+0.37387337j,
#         0.86325601+0.19591483j,  0.91660911+0.08673001j])

# %%
impulse_channel = np.fft.ifft(freq_response)
impulse_channel
# Out:
# array([ 5.07713572e-01-5.02585435e-04j,  2.48736902e-01-3.08266505e-04j,
#         5.80060537e-03+4.19838022e-03j,  2.42710344e-01-2.18988373e-03j,
#        -2.26628229e-03-1.71164617e-03j,  4.11222687e-04+2.82934832e-04j,
#         1.32189626e-03-1.88413740e-03j,  3.60308808e-03+1.32245978e-03j,
#         8.21618802e-04+8.43986256e-03j,  7.98964431e-03-6.71051620e-03j,
#        -3.78091837e-03+6.55615682e-03j,  1.39450251e-02+4.81274281e-04j,
#         4.33231942e-03+2.49373606e-03j,  8.36443229e-03+1.18340426e-02j,
#        -5.66388509e-03+4.53254349e-03j, -2.64677036e-03+6.20358755e-03j,
#         1.53144813e-03+8.65027949e-03j,  2.66914456e-03+8.62635196e-04j,
#         7.86067631e-03+9.61311059e-03j,  1.43317172e-03-3.87251414e-03j,
#        -5.11262970e-03+3.31226159e-03j, -8.97929638e-04+1.76793832e-03j,
#         1.49687955e-04-1.23827130e-03j, -1.04071859e-02-1.37965297e-04j,
#         1.27250205e-02-2.88313023e-03j,  1.18338171e-03-4.54605790e-03j,
#         1.88477137e-02-5.72838804e-05j,  3.82631623e-03+4.41522361e-03j,
#         4.70134159e-03+7.24573879e-04j, -7.07378624e-03+3.51780668e-03j,
#        -9.57702974e-04+5.20609404e-03j, -5.37879223e-03+2.58960374e-03j,
#         6.14841552e-04+4.14135723e-03j,  2.10757449e-03+8.55525734e-04j,
#         4.03634284e-04+1.68244304e-03j, -1.99373003e-03+4.22005070e-03j,
#         1.19871847e-02+1.22698498e-02j,  5.07333710e-04-6.40764407e-03j,
#         4.83803966e-03+8.88320545e-03j,  7.15252737e-04-6.36029083e-03j,
#         3.94821367e-03-3.55333376e-03j, -4.68484369e-03-1.18694999e-02j,
#        -2.64180442e-03-5.86967870e-03j,  1.24846942e-03-5.74595147e-03j,
#        -3.84044601e-03-1.10940686e-02j,  1.38052794e-03+1.74517813e-04j,
#        -5.68274241e-03-5.69794655e-03j,  2.94481155e-03-9.25594189e-04j])

# %%
impulse_channel[0:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c88ecbabec39> in <module>
# ----> 1 impulse_channel[0:4]
#
# NameError: name 'impulse_channel' is not defined

# %%
print(np.linalg.norm(impulse_channel[0]),np.linalg.norm(impulse_channel[1]), np.linalg.norm(impulse_channel[2]), np.linalg.norm(impulse_channel[3]))
# Out:
# 0.5077138205558696 0.2487370930333753 0.007160546008247314 0.24272022277185737

# %%
sim_channel
# Out:
# array([0.5 , 0.25, 0.  , 0.25])
